# %% [markdown]
# ## Задание №1. Первичный анализ данных с использованием описательных статистик и визуализации

# %% [markdown]
# ## Посмотрим на данные

# %%
import os
os.chdir("C:/Users/79811/anaconda3/")

# %%
# View first 20 rows
from pandas import read_csv
filename = "bezdekIris (2).data"
names = ['Длина чашелистика','Ширина чашелистика','Длина лепестка','Ширина лепестка','Класс']
data = read_csv(filename, names=names)
peek = data.head(20)
print(peek)
# Out:
#     Длина чашелистика  Ширина чашелистика  Длина лепестка  Ширина лепестка        Класс
# 0                 5.1                 3.5             1.4              0.2  Iris-setosa
# 1                 4.9                 3.0             1.4              0.2  Iris-setosa
# 2                 4.7                 3.2             1.3              0.2  Iris-setosa
# 3                 4.6                 3.1             1.5              0.2  Iris-setosa
# 4                 5.0                 3.6             1.4              0.2  Iris-setosa
# 5                 5.4                 3.9             1.7              0.4  Iris-setosa
# 6                 4.6                 3.4             1.4              0.3  Iris-setosa
# 7                 5.0                 3.4             1.5              0.2  Iris-setosa
# 8                 4.4                 2.9             1.4              0.2  Iris-setosa
# 9                 4.9                 3.1             1.5              0.1  Iris-setosa
# 10                5.4                 3.7             1.5              0.2  Iris-setosa
# 11                4.8                 3.4             1.6              0.2  Iris-setosa
# 12                4.8                 3.0             1.4              0.1  Iris-setosa
# 13                4.3                 3.0             1.1              0.1  Iris-setosa
# 14                5.8                 4.0             1.2              0.2  Iris-setosa
# 15                5.7                 4.4             1.5              0.4  Iris-setosa
# 16                5.4                 3.9             1.3              0.4  Iris-setosa
# 17                5.1                 3.5             1.4              0.3  Iris-setosa
# 18                5.7                 3.8             1.7              0.3  Iris-setosa
# 19                5.1                 3.8             1.5              0.3  Iris-setosa

# %% [markdown]
# ## Размерность данных

# %%
# Dimensions of your data
from pandas import read_csv
filename = "bezdekIris (2).data"
names = ['Длина чашелистика','Ширина чашелистика','Длина лепестка','Ширина лепестка','Класс']
data = read_csv(filename, names=names)
shape = data.shape
print(shape)
# Out:
# (150, 5)

# %% [markdown]
# ## Типы данных

# %%
# Data Types for Each Attribute
from pandas import read_csv
filename = "bezdekIris (2).data"
names = ['Длина чашелистика','Ширина чашелистика','Длина лепестка','Ширина лепестка','Класс']
data = read_csv(filename, names=names)
types = data.dtypes
print(types)
# Out:
# Длина чашелистика     float64
# Ширина чашелистика    float64
# Длина лепестка        float64
# Ширина лепестка       float64
# Класс                  object
# dtype: object

# %% [markdown]
# ## Описательные статистики

# %%
# Statistical Summary
from pandas import read_csv
from pandas import set_option
filename = "bezdekIris (2).data"
names = ['Длина чашелистика','Ширина чашелистика','Длина лепестка','Ширина лепестка','Класс']
data = read_csv(filename, names=names)
set_option('display.width', 100)
set_option('precision', 3)
description = data.describe()
print(description)
# Out:
#        Длина чашелистика  Ширина чашелистика  Длина лепестка  Ширина лепестка
# count            150.000             150.000         150.000          150.000
# mean               5.843               3.057           3.758            1.199
# std                0.828               0.436           1.765            0.762
# min                4.300               2.000           1.000            0.100
# 25%                5.100               2.800           1.600            0.300
# 50%                5.800               3.000           4.350            1.300
# 75%                6.400               3.300           5.100            1.800
# max                7.900               4.400           6.900            2.500

# %% [markdown]
# ## Распределение данных по классам

# %%
# Class Distribution
from pandas import read_csv
filename = "bezdekIris (2).data"
names = ['Длина чашелистика','Ширина чашелистика','Длина лепестка','Ширина лепестка','Класс']
data = read_csv(filename, names=names)
class_counts = data.groupby('Класс').size()
print(class_counts)
# Out:
# Класс
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# ## Корреляция между признаками

# %%
# Pairwise Pearson correlations
from pandas import read_csv
from pandas import set_option
filename = "bezdekIris (2).data"
names = ['Длина чашелистика','Ширина чашелистика','Длина лепестка','Ширина лепестка','Класс']
data = read_csv(filename, names=names)
set_option('display.width', 100)
set_option('precision', 3)
correlations = data.corr(method='pearson')
print(correlations)
# Out:
#                     Длина чашелистика  Ширина чашелистика  Длина лепестка  Ширина лепестка
# Длина чашелистика               1.000              -0.118           0.872            0.818
# Ширина чашелистика             -0.118               1.000          -0.428           -0.366
# Длина лепестка                  0.872              -0.428           1.000            0.963
# Ширина лепестка                 0.818              -0.366           0.963            1.000

# %% [markdown]
# ## Ассиметрия одномерных распределений

# %%
# Skew for each attribute
from pandas import read_csv
filename = "bezdekIris (2).data"
names = ['Длина чашелистика','Ширина чашелистика','Длина лепестка','Ширина лепестка','Класс']
data = read_csv(filename, names=names)
skew = data.skew()
print(skew)
# Out:
# Длина чашелистика     0.315
# Ширина чашелистика    0.319
# Длина лепестка       -0.275
# Ширина лепестка      -0.103
# dtype: float64
# C:\Users\41BC~1\AppData\Local\Temp/ipykernel_3708/2649779937.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   skew = data.skew()

# %% [markdown]
# ## Univariate Plots (одномерные графики распределений

# %% [markdown]
# ### Histograms (гистограммы)

# %%
import os
os.chdir("C:/Users/79811/anaconda3/")

# %%
# Univariate Histograms
from matplotlib import pyplot
from pandas import read_csv
filename = "bezdekIris (2).data"
names = ['Длина чашелистика','Ширина чашелистика','Длина лепестка','Ширина лепестка','Класс']
data = read_csv(filename, names=names)
data.hist()
pyplot.show()

# %% [markdown]
# ### Density Plots (ядерные оценки плотности)

# %%
# Univariate Density Plots
from matplotlib import pyplot
from pandas import read_csv
filename = "bezdekIris (2).data"
names = ['Длина чашелистика','Ширина чашелистика','Длина лепестка','Ширина лепестка','Класс']
data = read_csv(filename, names=names)
data.plot(kind='density', subplots=True, layout=(3,3), sharex=False)
pyplot.show()

# %% [markdown]
# ### Box and Whisker Plots (ящики с усами)

# %%
# Box and Whisker Plots
from matplotlib import pyplot
from pandas import read_csv
filename = "bezdekIris (2).data"
names = ['Длина чашелистика','Ширина чашелистика','Длина лепестка','Ширина лепестка','Класс']
data = read_csv(filename, names=names)
data.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False)
pyplot.show()

# %% [markdown]
# ## Multivariate Plots (многомерные графики распределений)

# %% [markdown]
# ### Correlation Matrix Plot (коррелограмма)

# %%
# Correlation Matrix Plot
from matplotlib import pyplot
from pandas import read_csv
import numpy
filename = "bezdekIris (2).data"
names = ['Длина чашелистика', 'Ширина чашелистика', 'Длина лепестка', 'Ширина лепестка', 'Класс']
data = read_csv(filename, names=names)
correlations = data.corr()
# plot correlation matrix
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,5,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_xticklabels(names)
pyplot.show()

# %%
# Correlation Matrix Plot (generic)
from matplotlib import pyplot
from pandas import read_csv
filename = "bezdekIris (2).data"
names = ['Длина чашелистика','Ширина чашелистика','Длина лепестка','Ширина лепестка','Класс']
data = read_csv(filename, names=names)
correlations = data.corr()
# plot correlation matrix
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
pyplot.show()

# %% [markdown]
# ### Scatter Plot Matrix (диаграмма рассеяния)

# %%
# Scatterplot Matrix
from matplotlib import pyplot
from pandas import read_csv
from pandas.plotting import scatter_matrix
filename = "bezdekIris (2).data"
names = ['Длина чашелистика','Ширина чашелистика','Длина лепестка','Ширина лепестка','Класс']
data = read_csv(filename, names=names)
scatter_matrix(data)
pyplot.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig = plt.figure(figsize=(8,6))
sns.heatmap(data.corr(), annot = True)
plt.show()
